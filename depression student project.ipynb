# %%
import pandas as pd

# %%
cd Downloads/
# Out:
# C:\Users\aa\Downloads

# %%
data=pd.read_csv("Depression Student Dataset.csv")

# %%
data
# Out:
#      Gender  Age  Academic Pressure  Study Satisfaction     Sleep Duration  \
# 0      Male   28                2.0                 4.0          7-8 hours
# 1      Male   28                4.0                 5.0          5-6 hours
# 2      Male   25                1.0                 3.0          5-6 hours
# 3      Male   23                1.0                 4.0  More than 8 hours
# 4    Female   31                1.0                 5.0  More than 8 hours
# ..      ...  ...                ...                 ...                ...
# 497    Male   26                5.0                 2.0  More than 8 hours
# 498    Male   24                2.0                 1.0  Less than 5 hours
# 499  Female   23                3.0                 5.0          5-6 hours
# 500    Male   33                4.0                 4.0  More than 8 hours
# 501    Male   18                5.0                 3.0  More than 8 hours
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 502 non-null    object
#  1   Age                                    502 non-null    int64
#  2   Academic Pressure                      502 non-null    float64
#  3   Study Satisfaction                     502 non-null    float64
#  4   Sleep Duration                         502 non-null    object
#  5   Dietary Habits                         502 non-null    object
#  6   Have you ever had suicidal thoughts ?  502 non-null    object
#  7   Study Hours                            502 non-null    int64
#  8   Financial Stress                       502 non-null    int64
#  9   Family History of Mental Illness       502 non-null    object
# ...

# %%
data.describe()
# Out:
#               Age  Academic Pressure  Study Satisfaction  Study Hours  \
# count  502.000000         502.000000          502.000000   502.000000
# mean    26.241036           3.003984            3.075697     6.404382
# std      4.896501           1.390007            1.373490     3.742434
# min     18.000000           1.000000            1.000000     0.000000
# 25%     22.000000           2.000000            2.000000     3.000000
# 50%     26.500000           3.000000            3.000000     7.000000
# 75%     30.000000           4.000000            4.000000    10.000000
# max     34.000000           5.000000            5.000000    12.000000
#
#        Financial Stress
# count        502.000000
# mean           2.928287
# std            1.425053
# min            1.000000
# 25%            2.000000
# 50%            3.000000
# 75%            4.000000
# max            5.000000

# %%
data.isnull().sum()
# Out:
# Gender                                   0
# Age                                      0
# Academic Pressure                        0
# Study Satisfaction                       0
# Sleep Duration                           0
# Dietary Habits                           0
# Have you ever had suicidal thoughts ?    0
# Study Hours                              0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Gender', 'Age', 'Academic Pressure', 'Study Satisfaction',
#        'Sleep Duration', 'Dietary Habits',
#        'Have you ever had suicidal thoughts ?', 'Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
data.dropna()
# Out:
#      Gender  Age  Academic Pressure  Study Satisfaction     Sleep Duration  \
# 0      Male   28                2.0                 4.0          7-8 hours
# 1      Male   28                4.0                 5.0          5-6 hours
# 2      Male   25                1.0                 3.0          5-6 hours
# 3      Male   23                1.0                 4.0  More than 8 hours
# 4    Female   31                1.0                 5.0  More than 8 hours
# ..      ...  ...                ...                 ...                ...
# 497    Male   26                5.0                 2.0  More than 8 hours
# 498    Male   24                2.0                 1.0  Less than 5 hours
# 499  Female   23                3.0                 5.0          5-6 hours
# 500    Male   33                4.0                 4.0  More than 8 hours
# 501    Male   18                5.0                 3.0  More than 8 hours
#
# ...

# %%
data.tail(10)
# Out:
#      Gender  Age  Academic Pressure  Study Satisfaction     Sleep Duration  \
# 492  Female   27                2.0                 3.0          5-6 hours
# 493  Female   21                5.0                 1.0          5-6 hours
# 494    Male   34                4.0                 1.0          7-8 hours
# 495  Female   28                3.0                 4.0          7-8 hours
# 496    Male   29                3.0                 1.0          7-8 hours
# 497    Male   26                5.0                 2.0  More than 8 hours
# 498    Male   24                2.0                 1.0  Less than 5 hours
# 499  Female   23                3.0                 5.0          5-6 hours
# 500    Male   33                4.0                 4.0  More than 8 hours
# 501    Male   18                5.0                 3.0  More than 8 hours
#
#     Dietary Habits Have you ever had suicidal thoughts ?  Study Hours  \
# 492      Unhealthy                                    No           11
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=502, step=1)

# %%
data.isnull()
# Out:
#      Gender    Age  Academic Pressure  Study Satisfaction  Sleep Duration  \
# 0     False  False              False               False           False
# 1     False  False              False               False           False
# 2     False  False              False               False           False
# 3     False  False              False               False           False
# 4     False  False              False               False           False
# ..      ...    ...                ...                 ...             ...
# 497   False  False              False               False           False
# 498   False  False              False               False           False
# 499   False  False              False               False           False
# 500   False  False              False               False           False
# 501   False  False              False               False           False
#
#      Dietary Habits  Have you ever had suicidal thoughts ?  Study Hours  \
# ...

# %%
data.shape
# Out:
# (502, 11)

# %%
data=data.rename({"Financial Stress":"Paisa"},axis=1)

# %%
data["Paisa"].sort_values
# Out:
# <bound method Series.sort_values of 0      2
# 1      1
# 2      4
# 3      2
# 4      2
#       ..
# 497    3
# 498    5
# 499    5
# 500    1
# 501    2
# Name: Paisa, Length: 502, dtype: int64>

# %%
data
# Out:
#      Gender  Age  Academic Pressure  Study Satisfaction     Sleep Duration  \
# 0      Male   28                2.0                 4.0          7-8 hours
# 1      Male   28                4.0                 5.0          5-6 hours
# 2      Male   25                1.0                 3.0          5-6 hours
# 3      Male   23                1.0                 4.0  More than 8 hours
# 4    Female   31                1.0                 5.0  More than 8 hours
# ..      ...  ...                ...                 ...                ...
# 497    Male   26                5.0                 2.0  More than 8 hours
# 498    Male   24                2.0                 1.0  Less than 5 hours
# 499  Female   23                3.0                 5.0          5-6 hours
# 500    Male   33                4.0                 4.0  More than 8 hours
# 501    Male   18                5.0                 3.0  More than 8 hours
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 502 non-null    object
#  1   Age                                    502 non-null    int64
#  2   Academic Pressure                      502 non-null    float64
#  3   Study Satisfaction                     502 non-null    float64
#  4   Sleep Duration                         502 non-null    object
#  5   Dietary Habits                         502 non-null    object
#  6   Have you ever had suicidal thoughts ?  502 non-null    object
#  7   Study Hours                            502 non-null    int64
#  8   Paisa                                  502 non-null    int64
#  9   Family History of Mental Illness       502 non-null    object
# ...

# %%
data_num=data.select_dtypes(["float64","object"])

# %%
data_cat=data.select_dtypes(object)

# %%
x=data.drop(["Depression"],axis=1)
y=data["Depression"]

# %%
x
# Out:
#      Gender  Age  Academic Pressure  Study Satisfaction  Sleep Duration  \
# 0         1   28                2.0                 4.0               1
# 1         1   28                4.0                 5.0               0
# 2         1   25                1.0                 3.0               0
# 3         1   23                1.0                 4.0               3
# 4         0   31                1.0                 5.0               3
# ..      ...  ...                ...                 ...             ...
# 497       1   26                5.0                 2.0               3
# 498       1   24                2.0                 1.0               2
# 499       0   23                3.0                 5.0               0
# 500       1   33                4.0                 4.0               3
# 501       1   18                5.0                 3.0               3
#
#      Dietary Habits  Have you ever had suicidal thoughts ?  Study Hours  \
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 497    1
# 498    1
# 499    0
# 500    0
# 501    1
# Name: Depression, Length: 502, dtype: int32

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()

# %%
print(label_encoder)
# Out:
# LabelEncoder()

# %%
data["Gender"]=label_encoder.fit_transform(data["Gender"])

# %%
data["Sleep Duration"]=label_encoder.fit_transform(data["Sleep Duration"])

# %%
data["Dietary Habits"]=label_encoder.fit_transform(data["Dietary Habits"])

# %%
data["Have you ever had suicidal thoughts ?"]=label_encoder.fit_transform(data["Have you ever had suicidal thoughts ?"])

# %%
data["Family History of Mental Illness"]=label_encoder.fit_transform(data["Family History of Mental Illness"])

# %%
data["Depression"]=label_encoder.fit_transform(data["Depression"])

# %%
data
# Out:
#      Gender  Age  Academic Pressure  Study Satisfaction  Sleep Duration  \
# 0         1   28                2.0                 4.0               1
# 1         1   28                4.0                 5.0               0
# 2         1   25                1.0                 3.0               0
# 3         1   23                1.0                 4.0               3
# 4         0   31                1.0                 5.0               3
# ..      ...  ...                ...                 ...             ...
# 497       1   26                5.0                 2.0               3
# 498       1   24                2.0                 1.0               2
# 499       0   23                3.0                 5.0               0
# 500       1   33                4.0                 4.0               3
# 501       1   18                5.0                 3.0               3
#
#      Dietary Habits  Have you ever had suicidal thoughts ?  Study Hours  \
# ...

# %%
data_cat
# Out:
#      Gender     Sleep Duration Dietary Habits  \
# 0      Male          7-8 hours       Moderate
# 1      Male          5-6 hours        Healthy
# 2      Male          5-6 hours      Unhealthy
# 3      Male  More than 8 hours      Unhealthy
# 4    Female  More than 8 hours        Healthy
# ..      ...                ...            ...
# 497    Male  More than 8 hours      Unhealthy
# 498    Male  Less than 5 hours      Unhealthy
# 499  Female          5-6 hours        Healthy
# 500    Male  More than 8 hours        Healthy
# 501    Male  More than 8 hours      Unhealthy
#
#     Have you ever had suicidal thoughts ? Family History of Mental Illness  \
# 0                                     Yes                              Yes
# 1                                     Yes                              Yes
# 2                                     Yes                               No
# 3                                     Yes                              Yes
# ...

# %%
data.head()
# Out:
#    Gender  Age  Academic Pressure  Study Satisfaction  Sleep Duration  \
# 0       1   28                2.0                 4.0               1
# 1       1   28                4.0                 5.0               0
# 2       1   25                1.0                 3.0               0
# 3       1   23                1.0                 4.0               3
# 4       0   31                1.0                 5.0               3
#
#    Dietary Habits  Have you ever had suicidal thoughts ?  Study Hours  Paisa  \
# 0               1                                      1            9      2
# 1               0                                      1            7      1
# 2               2                                      1           10      4
# 3               2                                      1            7      2
# 4               0                                      1            4      2
#
#    Family History of Mental Illness  Depression
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.9675810473815462

# %%
model.score(x_test,y_test)
# Out:
# 0.9702970297029703

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(data["Depression"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26d75f588f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26d75f59130>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26d75f28e60>],
#  'medians': [<matplotlib.lines.Line2D at 0x26d75f59610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26d75f598e0>],
#  'means': []}

# %%
plt.scatter(data["Gender"],data["Depression"])

# %%
from sklearn.model_selection import train_test_split,KFold,cross_val_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=43)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
model.score(x_train,y_train)
# Out:
# 0.8428927680798005

# %%
model.score(x_test,y_test)
# Out:
# 0.8118811881188119

# %%
k=KFold(n_splits=5)

# %%
cross_val_score(model,x,y,cv=k).mean()
# Out:
# 0.7612079207920791

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
model=Lasso()

# %%
model.fit(x_train,y_train)
# Out:
# Lasso()

# %%
model.score(x_train,y_train)
# Out:
# 0.0

# %%
model.score(x_test,y_test)
# Out:
# -0.0017800310273619058

# %%
data["Gender"],data["Depression"].value_counts().plot(kind="bar")
# Out:
# (0      1
#  1      1
#  2      1
#  3      1
#  4      0
#        ..
#  497    1
#  498    1
#  499    0
#  500    1
#  501    1
#  Name: Gender, Length: 502, dtype: int64,
#  <Axes: xlabel='Depression'>)

# %%
import seaborn as sns

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
data.groupby("Depression").mean("numeric_only")
# Out:
#               Gender        Age  Academic Pressure  Study Satisfaction  \
# Depression
# 0           0.516000  27.300000           2.340000            3.480000
# 1           0.547619  25.190476           3.662698            2.674603
#
#             Sleep Duration  Dietary Habits  \
# Depression
# 0                 1.568000        0.864000
# 1                 1.452381        1.166667
#
#             Have you ever had suicidal thoughts ?  Study Hours     Paisa  \
# Depression
# 0                                           0.284     5.652000  2.504000
# 1                                           0.750     7.150794  3.349206
#
#             Family History of Mental Illness
# Depression
# 0                                      0.444
# 1                                      0.500

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.686241866358912

# %%
model.score(x_test,y_test)
# Out:
# 0.6308879362589963

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data["Gender"],data["Depression"])

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import seaborn as sns

# %%
sns.histplot(data["Depression"])
# Out:
# <Axes: xlabel='Depression', ylabel='Count'>

# %%
plt.scatter(data["Depression"],data["Gender"])

# %%
data["Depression"].sum()
# Out:
# 252

# %%
data["Depression"].min()
# Out:
# 0

# %%
data["Depression"].sort_values()
# Out:
# 0      0
# 208    0
# 399    0
# 400    0
# 401    0
#       ..
# 218    1
# 217    1
# 215    1
# 229    1
# 501    1
# Name: Depression, Length: 502, dtype: int64

# %%
data["Depression"].var()
# Out:
# 0.250495025884486

# %%
data.select_dtypes(include="float").corr()
# Out:
#                     Academic Pressure  Study Satisfaction
# Academic Pressure            1.000000           -0.101571
# Study Satisfaction          -0.101571            1.000000

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.686241866358912

# %%
model.score(x_test,y_test)
# Out:
# 0.6308879362589963

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier(n_neighbors=5)

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
model.score(x_train,y_train)
# Out:
# 0.8428927680798005

# %%
model.score(x_test,y_test)
# Out:
# 0.8118811881188119

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_score,recall_score

# %%
y_pred = model.predict(x_test)

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[42,  9],
#        [10, 40]], dtype=int64)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.8118811881188119

# %%
print(classification_report(y_pred,y_test,digits=5))
# Out:
#               precision    recall  f1-score   support
#
#            0    0.80769   0.82353   0.81553        51
#            1    0.81633   0.80000   0.80808        50
#
#     accuracy                        0.81188       101
#    macro avg    0.81201   0.81176   0.81181       101
# weighted avg    0.81197   0.81188   0.81184       101

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model=GaussianNB()

# %%
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(x_train,y_train)
# Out:
# 0.9326683291770573

# %%
model.score(x_test,y_test)
# Out:
# 0.8811881188118812

# %%
data
# Out:
#      Gender  Age  Academic Pressure  Study Satisfaction  Sleep Duration  \
# 0         1   28                2.0                 4.0               1
# 1         1   28                4.0                 5.0               0
# 2         1   25                1.0                 3.0               0
# 3         1   23                1.0                 4.0               3
# 4         0   31                1.0                 5.0               3
# ..      ...  ...                ...                 ...             ...
# 497       1   26                5.0                 2.0               3
# 498       1   24                2.0                 1.0               2
# 499       0   23                3.0                 5.0               0
# 500       1   33                4.0                 4.0               3
# 501       1   18                5.0                 3.0               3
#
#      Dietary Habits  Have you ever had suicidal thoughts ?  Study Hours  \
# ...

# %%
data["Academic Pressure"].sort_values
# Out:
# <bound method Series.sort_values of 0      2.0
# 1      4.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 497    5.0
# 498    2.0
# 499    3.0
# 500    4.0
# 501    5.0
# Name: Academic Pressure, Length: 502, dtype: float64>

# %%
data["Depression"].sum
# Out:
# <bound method Series.sum of 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 497    1
# 498    1
# 499    0
# 500    0
# 501    1
# Name: Depression, Length: 502, dtype: int64>

# %%
data["Depression"].min
# Out:
# <bound method Series.min of 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 497    1
# 498    1
# 499    0
# 500    0
# 501    1
# Name: Depression, Length: 502, dtype: int64>

# %%
if(20<10):
    print("yes")
    print("no")
elif(8>10):
    print(1)
else:
    print("bapu")
# Out:
# bapu

# %%
import numpy as np

# %%
import seaborn as sns

# %%
sns.relplot(x=data["Depression"],y=data["Age"],hue=data["Gender"])

# %%
sns.boxplot(data["Depression"])
# Out:
# <Axes: ylabel='Depression'>

# %%
data
# Out:
#      Gender  Age  Academic Pressure  Study Satisfaction  Sleep Duration  \
# 0         1   28                2.0                 4.0               1
# 1         1   28                4.0                 5.0               0
# 2         1   25                1.0                 3.0               0
# 3         1   23                1.0                 4.0               3
# 4         0   31                1.0                 5.0               3
# ..      ...  ...                ...                 ...             ...
# 497       1   26                5.0                 2.0               3
# 498       1   24                2.0                 1.0               2
# 499       0   23                3.0                 5.0               0
# 500       1   33                4.0                 4.0               3
# 501       1   18                5.0                 3.0               3
#
#      Dietary Habits  Have you ever had suicidal thoughts ?  Study Hours  \
# ...

# %%
sns.countplot(x=data["Depression"],stat="count",hue=data["Study Hours"])
# Out:
# <Axes: xlabel='Depression', ylabel='count'>

# %%
sns.swarmplot(data["Depression"])
# Out:
# <Axes: ylabel='Depression'>
