# %%
import pandas as pd

# %%
cd Downloads/
# Out:
# C:\Users\aa\Downloads

# %%
data=pd.read_csv("ML Linear Regression Home Price Prediction & Analysis Project  Resource16932049360 (1).csv")

# %%
data.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %%
data = data.drop(['Address','Date','Postcode','YearBuilt',"Lattitude","Longtitude"],axis=1)

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %%
data.shape
# Out:
# (34857, 15)

# %%
data.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
data[['Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car']] = data[['Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car']].fillna(0)
data['Landsize'] = data['Landsize'].fillna(data.Landsize.mean())
data['BuildingArea'] = data['BuildingArea'].fillna(data.BuildingArea.mean())

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (9244, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9244 entries, 2 to 34856
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         9244 non-null   object
#  1   Rooms          9244 non-null   int64
#  2   Type           9244 non-null   object
#  3   Price          9244 non-null   float64
#  4   Method         9244 non-null   object
#  5   SellerG        9244 non-null   object
#  6   Distance       9244 non-null   float64
#  7   Bedroom2       9244 non-null   float64
#  8   Bathroom       9244 non-null   float64
#  9   Car            9244 non-null   float64
#  10  Landsize       9244 non-null   float64
#  11  BuildingArea   9244 non-null   float64
#  12  CouncilArea    9244 non-null   object
#  13  Regionname     9244 non-null   object
#  14  Propertycount  9244 non-null   float64
# dtypes: float64(8), int64(1), object(6)
# memory usage: 1.1+ MB

# %%
data['Regionname'].unique()
# Out:
# array(['Northern Metropolitan', 'Western Metropolitan',
#        'Southern Metropolitan', 'Eastern Metropolitan',
#        'South-Eastern Metropolitan', 'Northern Victoria',
#        'Eastern Victoria', 'Western Victoria'], dtype=object)

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method  SellerG  Distance  Bedroom2  \
# 2      Abbotsford      2    h  1035000.0      S   Biggin       2.5       2.0
# 4      Abbotsford      3    h  1465000.0     SP   Biggin       2.5       3.0
# 6      Abbotsford      4    h  1600000.0     VB   Nelson       2.5       3.0
# 11     Abbotsford      3    h  1876000.0      S   Nelson       2.5       4.0
# 14     Abbotsford      2    h  1636000.0      S   Nelson       2.5       2.0
# ...           ...    ...  ...        ...    ...      ...       ...       ...
# 34847     Wollert      3    h   500000.0     PI      Ray      25.5       3.0
# 34849     Wollert      3    h   570000.0     SP       RW      25.5       3.0
# 34853  Yarraville      2    h   888000.0     SP  Sweeney       6.3       2.0
# 34854  Yarraville      2    t   705000.0      S      Jas       6.3       2.0
# 34856  Yarraville      2    h  1020000.0     PI       RW       6.3       2.0
#
# ...

# %%
data_cat=data.select_dtypes(object)
data_num=data.select_dtypes("int64","float64")
data_cat
# Out:
#            Suburb Type Method  SellerG               CouncilArea  \
# 2      Abbotsford    h      S   Biggin        Yarra City Council
# 4      Abbotsford    h     SP   Biggin        Yarra City Council
# 6      Abbotsford    h     VB   Nelson        Yarra City Council
# 11     Abbotsford    h      S   Nelson        Yarra City Council
# 14     Abbotsford    h      S   Nelson        Yarra City Council
# ...           ...  ...    ...      ...                       ...
# 34847     Wollert    h     PI      Ray   Whittlesea City Council
# 34849     Wollert    h     SP       RW   Whittlesea City Council
# 34853  Yarraville    h     SP  Sweeney  Maribyrnong City Council
# 34854  Yarraville    t      S      Jas  Maribyrnong City Council
# 34856  Yarraville    h     PI       RW  Maribyrnong City Council
#
#                   Regionname
# 2      Northern Metropolitan
# 4      Northern Metropolitan
# 6      Northern Metropolitan
# 11     Northern Metropolitan
# 14     Northern Metropolitan
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
loc=LabelEncoder()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data[["Suburb","Type","Method","SellerG","CouncilArea","Regionname"]]=data[["Suburb","Type","Method","SellerG","CouncilArea","Regionname"]].apply(loc.fit_transform)

# %%
data
# Out:
#        Suburb  Rooms  Type      Price  Method  SellerG  Distance  Bedroom2  \
# 2           0      2     0  1035000.0       1       22       2.5       2.0
# 4           0      3     0  1465000.0       3       22       2.5       3.0
# 6           0      4     0  1600000.0       4      148       2.5       3.0
# 11          0      3     0  1876000.0       1      148       2.5       4.0
# 14          0      2     0  1636000.0       1      148       2.5       2.0
# ...       ...    ...   ...        ...     ...      ...       ...       ...
# 34847     312      3     0   500000.0       0      186      25.5       3.0
# 34849     312      3     0   570000.0       3      183      25.5       3.0
# 34853     317      2     0   888000.0       3      208       6.3       2.0
# 34854     317      2     1   705000.0       1       99       6.3       2.0
# 34856     317      2     0  1020000.0       0      183       6.3       2.0
#
# ...

# %%
data.head()
# Out:
#     Suburb  Rooms  Type      Price  Method  SellerG  Distance  Bedroom2  \
# 2        0      2     0  1035000.0       1       22       2.5       2.0
# 4        0      3     0  1465000.0       3       22       2.5       3.0
# 6        0      4     0  1600000.0       4      148       2.5       3.0
# 11       0      3     0  1876000.0       1      148       2.5       4.0
# 14       0      2     0  1636000.0       1      148       2.5       2.0
#
#     Bathroom  Car  Landsize  BuildingArea  CouncilArea  Regionname  \
# 2        1.0  0.0     156.0          79.0           31           2
# 4        2.0  0.0     134.0         150.0           31           2
# 6        1.0  2.0     120.0         142.0           31           2
# 11       2.0  0.0     245.0         210.0           31           2
# 14       1.0  2.0     256.0         107.0           31           2
#
#     Propertycount
# 2          4019.0
# 4          4019.0
# 6          4019.0
# 11         4019.0
# 14         4019.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x=data.drop("Price",axis=1)
y=data["Price"]

# %%
from sklearn.model_selection import train_test_split,KFold,cross_val_score
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2)

# %%
x_train.shape
# Out:
# (6470, 14)

# %%
x_test.shape
# Out:
# (2774, 14)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test, y_test)
# Out:
# 0.41286528802341427

# %%
reg.score(x_train, y_train)
# Out:
# 0.4891269268657097

# %%
from sklearn.linear_model import Ridge

# %%
ridge_reg= Ridge(alpha=50, max_iter=100,)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=50, max_iter=100)

# %%
ridge_reg.score(x_test, y_test)
# Out:
# 0.41355496855982543

# %%
ridge_reg.score(x_train, y_train)
# Out:
# 0.4890276200006247

# %%
from sklearn.linear_model import Lasso

# %%
model=Lasso()

# %%
model.fit(x_train,y_train)
# Out:
# Lasso()

# %%
model.score(x_train,y_train)
# Out:
# 0.48912692671862146

# %%
model.score(x_test,y_test)
# Out:
# 0.4128661163612424

# %%
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
lis=[SVR,DecisionTreeRegressor,RandomForestRegressor,KNeighborsRegressor]

# %%
k=KFold(n_splits=5)

# %%
cross_val_score(model,x,y,cv=k).mean()
# Out:
# 0.3283743610280558

# %%
for i in lis:
    k=KFold(n_splits=5)
    print(i)
    print(cross_val_score(i(),x,y,cv=k).mean())
# Out:
# <class 'sklearn.svm._classes.SVR'>
# -0.09246271842802556
# <class 'sklearn.tree._classes.DecisionTreeRegressor'>
# 0.5145661272537053
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# 0.7724147102097902
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'>
# 0.4973073850920254

# %%
model=RandomForestRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(x_train,y_train)
# Out:
# 0.9750004813059987

# %%
model.score(x_test,y_test)
# Out:
# 0.7487452942214442

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
dic={"n_estimators":[100,150,200],"random_state":[10,20,30]}

# %%
random=RandomizedSearchCV(RandomForestRegressor(),param_distributions=dic,n_iter=10,cv=k,verbose=2)

# %%
random.fit(x,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END ..................n_estimators=100, random_state=10; total time=   6.7s
# [CV] END ..................n_estimators=100, random_state=10; total time=   6.7s
# [CV] END ..................n_estimators=100, random_state=10; total time=   6.4s
# [CV] END ..................n_estimators=100, random_state=10; total time=   6.6s
# [CV] END ..................n_estimators=100, random_state=10; total time=   7.9s
# [CV] END ..................n_estimators=100, random_state=20; total time=   6.7s
# [CV] END ..................n_estimators=100, random_state=20; total time=   6.5s
# [CV] END ..................n_estimators=100, random_state=20; total time=   6.7s
# [CV] END ..................n_estimators=100, random_state=20; total time=   6.4s
# [CV] END ..................n_estimators=100, random_state=20; total time=   9.3s
# [CV] END ..................n_estimators=100, random_state=30; total time=   6.6s
# ...
