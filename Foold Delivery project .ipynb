# %%
import pandas as pd

# %%
cd Downloads/
# Out:
# C:\Users\aa\Downloads

# %%
data=pd.read_csv("Food_Time_Data_Set.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           10000 non-null  object
#  1   Delivery_person_ID           10000 non-null  object
#  2   Delivery_person_Age          10000 non-null  float64
#  3   Delivery_person_Ratings      10000 non-null  float64
#  4   Restaurant_latitude          10000 non-null  float64
#  5   Restaurant_longitude         10000 non-null  float64
#  6   Delivery_location_latitude   10000 non-null  float64
#  7   Delivery_location_longitude  10000 non-null  float64
#  8   Type_of_order                10000 non-null  object
#  9   Type_of_vehicle              10000 non-null  object
#  10  temperature                  9995 non-null   float64
#  11  humidity                     9995 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# ID                                 1
# Delivery_person_ID                 1
# Delivery_person_Age                1
# Delivery_person_Ratings            1
# Restaurant_latitude                1
# Restaurant_longitude               1
# Delivery_location_latitude         1
# Delivery_location_longitude        1
# Type_of_order                      1
# Type_of_vehicle                    1
# temperature                        6
# humidity                           6
# precipitation                      6
# weather_description                6
# Unnamed: 14                    10001
# Traffic_Level                    916
# Distance (km)                    921
# TARGET                           542
# dtype: int64

# %%
data_filled = data.fillna(0)

# %%
data.isnull()
# Out:
#           ID  Delivery_person_ID  Delivery_person_Age  \
# 0      False               False                False
# 1      False               False                False
# 2      False               False                False
# 3      False               False                False
# 4      False               False                False
# ...      ...                 ...                  ...
# 9996   False               False                False
# 9997   False               False                False
# 9998   False               False                False
# 9999   False               False                False
# 10000   True                True                 True
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                        False                False                 False
# 1                        False                False                 False
# 2                        False                False                 False
# ...

# %%
data_cat=data.select_dtypes(object)
data_num=data.select_dtypes(["int64"],["float64"])

data_cat
# Out:
#          ID Delivery_person_ID Type_of_order Type_of_vehicle  \
# 0      4607     INDORES13DEL02        Snack      motorcycle
# 1      B379     BANGRES18DEL02        Snack         scooter
# 2      5D6D     BANGRES19DEL01       Drinks      motorcycle
# 3      7A6A    COIMBRES13DEL02       Buffet      motorcycle
# 4      70A2     CHENRES12DEL01        Snack         scooter
# ...     ...                ...           ...             ...
# 9996   11B4      VADRES13DEL03         Meal      motorcycle
# 9997   8336      HYDRES20DEL01         Meal      motorcycle
# 9998   338B      JAPRES18DEL03       Buffet         scooter
# 9999   3FB2      MUMRES11DEL03         Meal         scooter
# 10000   NaN                NaN           NaN             NaN
#
#       weather_description Traffic_Level       TARGET
# 0                    haze           Low  21.66666667
# 1                    mist     Very High  85.26666667
# 2                    mist           Low  28.58333333
# ...

# %%
data_cleaned_columns = data.dropna(axis=1)

# %%
data
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02                 37.0                      4.9
# 1      B379     BANGRES18DEL02                 34.0                      4.5
# 2      5D6D     BANGRES19DEL01                 23.0                      4.4
# 3      7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4      70A2     CHENRES12DEL01                 32.0                      4.6
# ...     ...                ...                  ...                      ...
# 9996   11B4      VADRES13DEL03                 32.0                      4.2
# 9997   8336      HYDRES20DEL01                 36.0                      4.7
# 9998   338B      JAPRES18DEL03                 37.0                      4.6
# 9999   3FB2      MUMRES11DEL03                 29.0                      4.7
# 10000   NaN                NaN                  NaN                      NaN
#
# ...

# %%
##for individual data columns derop

# %%
data.dropna(subset=['ID'], inplace=True)

# %% [markdown]
# ##for indivdual columns drop

# %%
data.drop('weather_description', axis=1, inplace=True)

# %%
data.drop('Unnamed: 14', axis=1, inplace=True)

# %%
data.drop('precipitation', axis=1, inplace=True)
data.drop('Traffic_Level', axis=1, inplace=True)

# %% [raw]
# ##for entire rows null values drop

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 1     B379     BANGRES18DEL02                 34.0                      4.5
# 2     5D6D     BANGRES19DEL01                 23.0                      4.4
# 3     7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4     70A2     CHENRES12DEL01                 32.0                      4.6
# 5     9BB4      HYDRES09DEL03                 22.0                      4.8
# ...    ...                ...                  ...                      ...
# 9995  4347      MUMRES07DEL01                 25.0                      4.0
# 9996  11B4      VADRES13DEL03                 32.0                      4.2
# 9997  8336      HYDRES20DEL01                 36.0                      4.7
# 9998  338B      JAPRES18DEL03                 37.0                      4.6
# 9999  3FB2      MUMRES11DEL03                 29.0                      4.7
#
# ...

# %%
data_cat=data.select_dtypes(object)
data_num=data.select_dtypes(["int64"],["float64"])

data_cat
# Out:
#         ID Delivery_person_ID Type_of_order Type_of_vehicle       TARGET
# 1     B379     BANGRES18DEL02        Snack         scooter   85.26666667
# 2     5D6D     BANGRES19DEL01       Drinks      motorcycle   28.58333333
# 3     7A6A    COIMBRES13DEL02       Buffet      motorcycle   35.18333333
# 4     70A2     CHENRES12DEL01        Snack         scooter         43.45
# 5     9BB4      HYDRES09DEL03       Buffet      motorcycle          30.6
# ...    ...                ...           ...             ...          ...
# 9995  4347      MUMRES07DEL01         Meal      motorcycle          18.2
# 9996  11B4      VADRES13DEL03         Meal      motorcycle   32.61666667
# 9997  8336      HYDRES20DEL01         Meal      motorcycle   12.01666667
# 9998  338B      JAPRES18DEL03       Buffet         scooter   51.06666667
# 9999  3FB2      MUMRES11DEL03         Meal         scooter          43.8
#
# [9035 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc=LabelEncoder()

# %%
data[["Delivery_person_ID","Type_of_vehicle","Type_of_order","ID"]]=data[["Delivery_person_ID","Type_of_vehicle","Type_of_order","ID"]].apply(enc.fit_transform)

# %%
data
# Out:
#         ID  Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 1     7087                 180                 34.0                      4.5
# 2     3256                 182                 23.0                      4.4
# 3     4519                 323                 38.0                      4.7
# 4     4069                 259                 32.0                      4.6
# 5     6019                 459                 22.0                      4.8
# ...    ...                 ...                  ...                      ...
# 9995  2198                 840                 25.0                      4.0
# 9996    98                1124                 32.0                      4.2
# 9997  4942                 487                 36.0                      4.7
# 9998  1545                 603                 37.0                      4.6
# 9999  2025                 851                 29.0                      4.7
#
# ...

# %%
data.hist();

# %%
import seaborn as sns

# %%
sns.boxplot(data);

# %%
import matplotlib.pyplot as plt

# %%
sns.boxplot(x=data["TARGET"])
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc=MinMaxScaler()

# %%
data=sc.fit_transform(data[["Distance (km)","TARGET"]])

# %%
pd.DataFrame(data).describe()
# Out:
#                  0            1
# count  9035.000000  9035.000000
# mean      0.218315     0.209634
# std       0.143633     0.108955
# min       0.000000     0.000000
# 25%       0.103963     0.130087
# 50%       0.203294     0.198640
# 75%       0.309487     0.275310
# max       1.000000     1.000000

# %%
import numpy as np

# %%
data=data.dropna()

# %%
X = data.drop('TARGET', axis=1)

# %%
(X.shape)
# Out:
# (9035, 13)

# %%
(y.shape)
# Out:
# (9035,)

# %%
y=data["TARGET"]

# %%
from sklearn.model_selection import train_test_split,KFold,cross_val_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
data
# Out:
#         ID  Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 1     7087                 180                 34.0                      4.5
# 2     3256                 182                 23.0                      4.4
# 3     4519                 323                 38.0                      4.7
# 4     4069                 259                 32.0                      4.6
# 5     6019                 459                 22.0                      4.8
# ...    ...                 ...                  ...                      ...
# 9995  2198                 840                 25.0                      4.0
# 9996    98                1124                 32.0                      4.2
# 9997  4942                 487                 36.0                      4.7
# 9998  1545                 603                 37.0                      4.6
# 9999  2025                 851                 29.0                      4.7
#
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train,y_train)
# Out:
# 0.7760757593756933

# %%
model.score(X_test,y_test)
# Out:
# 0.7842006983246037

# %%
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
lis=[SVR,DecisionTreeRegressor,RandomForestRegressor,KNeighborsRegressor]

# %%
k=KFold(n_splits=5)

# %%
cross_val_score(model,x,y,cv=k)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
cross_val_score(model,x,y,cv=k).mean()
# Out:
# 1.0

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
for i in lis:
    k=KFold(n_splits=5)
    print(i)
    print(cross_val_score(i(),x,y,cv=k).mean())
# Out:
# <class 'sklearn.svm._classes.SVR'>
# 0.003895740031877737
# <class 'sklearn.tree._classes.DecisionTreeRegressor'>
# 0.9986567560625599
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# 0.9997126159005865
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'>
# nan

# %%
model=RandomForestRegressor(n_estimators=100,random_state=40)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=40)

# %%
model.score(X_train,y_train)
# Out:
# 0.9896768810955869

# %%
model.score(X_test,y_test)
# Out:
# 0.927211095487442

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
dic={"n_estimators":[80,100,120],"random_state":[20,30,40]}

# %%
random=RandomizedSearchCV(RandomForestRegressor(),param_distributions=dic,n_iter=10,cv=k,verbose=2)

# %%
random.fit(x,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END ...................n_estimators=80, random_state=20; total time=   8.2s
# [CV] END ...................n_estimators=80, random_state=20; total time=   7.4s
# [CV] END ...................n_estimators=80, random_state=20; total time=   7.8s
# [CV] END ...................n_estimators=80, random_state=20; total time=   7.6s
# [CV] END ...................n_estimators=80, random_state=20; total time=   7.4s
# [CV] END ...................n_estimators=80, random_state=30; total time=   7.4s
# [CV] END ...................n_estimators=80, random_state=30; total time=   7.4s
# [CV] END ...................n_estimators=80, random_state=30; total time=   7.2s
# [CV] END ...................n_estimators=80, random_state=30; total time=   7.3s
# [CV] END ...................n_estimators=80, random_state=30; total time=   8.7s
# [CV] END ...................n_estimators=80, random_state=40; total time=   7.9s
# ...

# %%
random.best_estimator_
# Out:
# RandomForestRegressor(random_state=40)

# %%
pd.Series(model.feature_importances_,index=X.columns)
# Out:
# ID                             0.010310
# Delivery_person_ID             0.022203
# Delivery_person_Age            0.006922
# Delivery_person_Ratings        0.005472
# Restaurant_latitude            0.022297
# Restaurant_longitude           0.011363
# Delivery_location_latitude     0.022032
# Delivery_location_longitude    0.015151
# Type_of_order                  0.030371
# Type_of_vehicle                0.001921
# temperature                    0.068199
# humidity                       0.007918
# Distance (km)                  0.775841
# dtype: float64

# %%
pd.Series(model.feature_importances_,index=X.columns).plot(kind="bar")
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'MAE: {mae}, MSE: {mse}, R-squared: {r2}')
# Out:
# MAE: 3.271675244470935, MSE: 19.21982014928761, R-squared: 0.927211095487442
