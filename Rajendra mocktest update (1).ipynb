# %%
import pandas as pd

# %%
cd Downloads/
# Out:
# [WinError 2] The system cannot find the file specified: 'Downloads/'
# C:\Users\aa\Downloads

# %%
1. How can the dataset be imported into .ipynb code using the
pandas library?

# %%
data=pd.read_csv("Laptop Data (2) (1).csv")

# %%
data.head()
# Out:
#    Unnamed: 0                                               Name    Brand  \
# 0           0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1           1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 2           2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP
# 3           3  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung
# 4           4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
#
#    Price  Rating Processor_brand  Processor_gen  Core_per_processor  \
# 0  50399    4.30             AMD            5.0                 6.0
# 1  26690    4.45             AMD            7.0                 4.0
# 2  37012    4.65           Intel           12.0                 6.0
# 3  69990    4.75           Intel           12.0                12.0
# 4  23990    4.25           Intel           11.0                 2.0
#
#    Energy_Efficient_Units  RAM_GB RAM_type  Storage_capacity_GB Storage_type  \
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                  0
# Name                        0
# Brand                       0
# Price                       0
# Rating                      0
# Processor_brand             0
# Processor_gen             129
# Core_per_processor         12
# Energy_Efficient_Units      0
# RAM_GB                      0
# RAM_type                   22
# Storage_capacity_GB         0
# Storage_type                0
# Graphics_brand              2
# Display_size_inches         0
# Horizontal_pixel            0
# Vertical_pixel              0
# Touch_screen                0
# Operating_system            0
# dtype: int64

# %%
data.dropna()
# Out:
#       Unnamed: 0                                               Name    Brand  \
# 0              0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1              1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 2              2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP
# 3              3  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung
# 4              4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
# ...          ...                                                ...      ...
# 1015        1015              MSI Creator Z17 HX Studio A13V Laptop      MSI
# 1016        1016  MSI Stealth 16 Mercedes AMG Motorsport A13V Ga...      MSI
# 1017        1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP
# 1018        1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus
# 1019        1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1020 non-null   int64
#  1   Name                    1020 non-null   object
#  2   Brand                   1020 non-null   object
#  3   Price                   1020 non-null   int64
#  4   Rating                  1020 non-null   float64
#  5   Processor_brand         1020 non-null   object
#  6   Processor_gen           891 non-null    float64
#  7   Core_per_processor      1008 non-null   float64
#  8   Energy_Efficient_Units  1020 non-null   int64
#  9   RAM_GB                  1020 non-null   int64
#  10  RAM_type                998 non-null    object
#  11  Storage_capacity_GB     1020 non-null   int64
#  12  Storage_type            1020 non-null   object
#  13  Graphics_brand          1018 non-null   object
# ...

# %%
2Considering the nature of the dataset, would it be more
suitable to employ Supervised or Unsupervised Machine
Learning techniques?

# %% [markdown]
# ##This is a Supervised Regression Model because it uses labeled data to predict a continuous output

# %% [markdown]
# 3 3. If Supervised learning is deemed appropriate, what type of
# problem statement does it represent - Regression or
# Classification?

# %%
classification because the value of feature data in catagorical so we approched supervised model

# %%
data = data.drop(columns=['Unnamed: 0'])

# %%
data
# Out:
#                                                    Name    Brand   Price  \
# 0     HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP   50399
# 1     Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo   26690
# 2     HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP   37012
# 3     Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung   69990
# 4     Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno   23990
# ...                                                 ...      ...     ...
# 1015              MSI Creator Z17 HX Studio A13V Laptop      MSI  247999
# 1016  MSI Stealth 16 Mercedes AMG Motorsport A13V Ga...      MSI  292990
# 1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP   58800
# 1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus   54999
# 1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell   94490
#
#       Rating Processor_brand  Processor_gen  Core_per_processor  \
# ...

# %% [markdown]
# 4. What methods can be employed to assess the quality of the
# data, including its shape and data types?

# %%
data.shape
# Out:
# (877, 18)

# %%
data.isnull().sum()
# Out:
# Name                      0
# Brand                     0
# Price                     0
# Rating                    0
# Processor_brand           0
# Processor_gen             0
# Core_per_processor        0
# Energy_Efficient_Units    0
# RAM_GB                    0
# RAM_type                  0
# Storage_capacity_GB       0
# Storage_type              0
# Graphics_brand            0
# Display_size_inches       0
# Horizontal_pixel          0
# Vertical_pixel            0
# Touch_screen              0
# Operating_system          0
# dtype: int64

# %% [markdown]
# 5. How can null values within the dataset be identified and
# handled effectively?

# %%
data.isnull().sum()
# Out:
# Name                      0
# Brand                     0
# Price                     0
# Rating                    0
# Processor_brand           0
# Processor_gen             0
# Core_per_processor        0
# Energy_Efficient_Units    0
# RAM_GB                    0
# RAM_type                  0
# Storage_capacity_GB       0
# Storage_type              0
# Graphics_brand            0
# Display_size_inches       0
# Horizontal_pixel          0
# Vertical_pixel            0
# Touch_screen              0
# Operating_system          0
# dtype: int64

# %% [markdown]
# ##6. Appropriate form of analysis should be presented and
# descripted in form of comments headings and analysis?

# %% [markdown]
# data.head()

# %%
data.dropna(inplace=True)

# %% [raw]
# ##7. What techniques can be utilized to detect and eliminate any
# ##outliers present in the dataset?

# %%
from scipy import stats
data =data[(abs(stats.zscore(data['Price'])) < 3)]

# %%
data.describe()
# Out:
#                Price      Rating  Processor_gen  Core_per_processor  \
# count     850.000000  850.000000     850.000000          850.000000
# mean    71607.882353    4.371588      10.343529            8.148235
# std     39155.367641    0.232240       2.984390            3.619298
# min     18990.000000    3.950000       1.000000            2.000000
# 25%     44990.000000    4.162500       7.000000            6.000000
# 50%     60999.000000    4.350000      12.000000            8.000000
# 75%     86990.000000    4.550000      13.000000           10.000000
# max    261990.000000    4.750000      14.000000           24.000000
#
#        Energy_Efficient_Units      RAM_GB  Storage_capacity_GB  \
# count              850.000000  850.000000           850.000000
# mean                 0.001176   13.294118           608.978824
# std                  0.034300    4.896150           227.310100
# min                  0.000000    4.000000           128.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for column in ['Price', 'Processor_gen', 'Core_per_processor', 'RAM_GB']:
    plt.figure(figsize=(8, 4))
    sns.boxplot(data[column])
    plt.title(f"Boxplot of {column}")
    plt.show()

# %%
##8. In cases where categorical variables are present, how can they be encoded using appropriate techniques?

# %%
data_cat=data.select_dtypes(object)
data_num=data.select_dtypes(["int64"],["float64"])
data_cat
# Out:
#                                                    Name    Brand  \
# 0     HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1     Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 2     HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP
# 3     Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung
# 4     Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
# ...                                                 ...      ...
# 1014  Dell Inspiron 5430 IN5430YXVW9M01ORS1 Laptop (...     Dell
# 1015              MSI Creator Z17 HX Studio A13V Laptop      MSI
# 1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP
# 1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus
# 1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell
#
#      Processor_brand RAM_type Storage_type Graphics_brand Operating_system
# 0                AMD     DDR4          SSD            AMD    Windows 11 OS
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()

# %%
data["Name"]=label_encoder.fit_transform(data["Name"])

# %%
data["Brand"]=label_encoder.fit_transform(data["Brand"])
data["Processor_brand"]=label_encoder.fit_transform(data["Processor_brand"])
data["RAM_type"]=label_encoder.fit_transform(data["RAM_type"])
data["Storage_type"]=label_encoder.fit_transform(data["Storage_type"])
data["Graphics_brand"]=label_encoder.fit_transform(data["Graphics_brand"])
data["Operating_system"]=label_encoder.fit_transform(data["Operating_system"])
data["Touch_screen"]=label_encoder.fit_transform(data["Touch_screen"])

# %% [markdown]
# 9. When necessary, how can the data be scaled using appropriate
# scaling techniques?

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_columns = ["Price", "RAM_GB","Storage_capacity_GB"]
data[scaled_columns] = scaler.fit_transform(data[scaled_columns])

# %%
data.describe()
# Out:
#             Name       Brand         Price      Rating  Processor_brand  \
# count  850.00000  850.000000  8.500000e+02  850.000000       850.000000
# mean   424.50000    9.681176  2.507798e-17    4.371588         0.712941
# std    245.51816    5.068738  1.000589e+00    0.232240         0.452656
# min      0.00000    0.000000 -1.344614e+00    3.950000         0.000000
# 25%    212.25000    7.000000 -6.802019e-01    4.162500         0.000000
# 50%    424.50000   10.000000 -2.711028e-01    4.350000         1.000000
# 75%    636.75000   14.000000  3.930795e-01    4.550000         1.000000
# max    849.00000   24.000000  4.865085e+00    4.750000         1.000000
#
#        Processor_gen  Core_per_processor  Energy_Efficient_Units  \
# count     850.000000          850.000000              850.000000
# mean       10.343529            8.148235                0.001176
# std         2.984390            3.619298                0.034300
# ...

# %% [markdown]
# 10. How can the dataset be divided into predictors and target
# variables?

# %%
x=data.drop("Price",axis=1)
y=data["Price"]

# %% [markdown]
# 11. What is the recommended approach for dividing the
# dataset into training and testing sets?

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=40)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor(n_estimators=100, random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
model.score(x_train,y_train)
# Out:
# 0.959486385057002

# %%
model.score(x_test,y_test)
# Out:
# 0.7207904429590455

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = model.predict(x_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'MAE: {mae}, MSE: {mse}, R-squared: {r2}')
# Out:
# MAE: 0.29150389499203677, MSE: 0.26440732799409455, R-squared: 0.7207904429590455

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
}

grid_search = GridSearchCV(RandomForestRegressor(), param_grid, cv=5, verbose=1)
grid_search.fit(x_train, y_train)

best_model = grid_search.best_estimator_
print(f'Best parameters: {grid_search.best_params_}')
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_depth': None, 'n_estimators': 100}
